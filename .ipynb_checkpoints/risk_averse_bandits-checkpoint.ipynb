# %%
from IPython.core.display import HTML
display(HTML('<style>.container { width:95% !important; } </style>'))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; } </style>

# %%
from MAB import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Parameters and aliases for all algorithms

# %%
# Enter the parameters of each algorithms
mapping = {'RAG': GaussianRAMAB}
mapping_name = {'RAG': 'Gaussian'}

# %% [markdown]
# ## Entropic Risk Measure

# %% [markdown]
# ### Manual runs of algorithms

# %%
bandit = 'RAG'

# risk aversion level
alpha = 1.0

# parameters for the arms distribution
# (mu, sigma, alpha)
p = [[0.0, 1.2, alpha], [0.7, 2.0, alpha]]
T = 500  # Horizon
N = 1  # Number of MC runs
step = 25  # If results are saved trajectories are stored for all rounds such that t%step=0

model = mapping[bandit](p, 'erm')

f = lambda t: np.log(2 * np.exp(1) * (t + np.exp(1)) * t ** 2 / 0.5) 
r, _ = model.MC_regret('erm_ucb', N, T, {'f': f}, step, 'erm')
# r, _ = model.MC_regret('RB_SDA', N, T, {}, step, 'erm')
res = pd.DataFrame([r]).T
res.columns = ['ra_ucb']
# res.columns = ['RB_SDA']
# Out:
# Computing 1 simulations: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it]

# %%
with sns.axes_style('darkgrid'):
    fig, ax = plt.subplots(figsize=(11, 7), nrows=1, ncols=1)

    res.plot(ax=ax)
    
    ax.legend(loc='lower right')
    ax.set_title('Average cumulative entropic regret over {} runs for {:s} bandit'.format(N, mapping_name[bandit]))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Parallelized runs of multiple algorithms on the same bandit

# %%
# Enter the parameters of each algorithms
param = {
    'RB_SDA': {}, 
    'erm_ucb': {'f': lambda t: np.log(2 * np.exp(1) * (t + np.exp(1)) * t ** 2 / 0.5)}
}

bandit = 'RAG'

# risk aversion level
alpha = 1.0

# parameters for the arms distribution
# (mu, sigma, alpha)
p = [[0.0, 1.2, alpha], [0.7, 2.0, alpha]]
T = 500  # Horizon
N = 1  # Number of MC runs
step = 25  # If results are saved trajectories are stored for all rounds such that t%step=0

algs = ['erm_ucb', 'RB_SDA']  # Select some Algorithms (check param file for availability)

res, traj = multiprocess_MC(
    (bandit, p, T, N, algs, param, step, 'erm', False),
    plot=False, 
    caption=None,
)

# res, traj = MC_xp(
#     (bandit, p, T, N, algs, param, step, 'erm', False),
#     plot=False, 
#     caption=None,
# )
# Out:
# Running on 4 cores
# Execution time: 10.190430879592896 seconds

# %%
with sns.axes_style('darkgrid'):
    fig, ax = plt.subplots(figsize=(11, 7), nrows=1, ncols=1)

    res.plot(ax=ax)
    ax.legend(loc='lower right')
    ax.set_title(
        'Average cumulative regret over {} runs for {:s} bandit\nEntropic risk measures : {:.2f} vs {:.2f}'.format(
            N, 
            mapping_name[bandit],
            model.MAB[0].risk_measures['erm'],
            model.MAB[1].risk_measures['erm'],
        )
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## CVaR

# %%
bandit = 'RAG'

# risk aversion level
alpha = 0.05

# parameters for the arms distribution
# (mu, sigma, alpha)
p = [[0.0, 1.2, alpha], [0.7, 2.0, alpha]]

T = 10000  # Horizon
N = 10  # Number of MC runs
step = 25  # If results are saved trajectories are stored for all rounds such that t%step=0

model = mapping[bandit](p, 'cvar')

r, _ = model.MC_regret('RB_SDA', N, T, {}, step, 'cvar')
res = pd.DataFrame([r]).T
res.columns = ['RB_SDA']
# Out:
# Computing 10 simulations: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]

# %%
with sns.axes_style('darkgrid'):
    fig, ax = plt.subplots(figsize=(11, 7), nrows=1, ncols=1)

    res.plot(ax=ax)
    
    ax.legend(loc='lower right')
    ax.set_title(
        'Average cumulative cVaR regret over {} runs for {:s} bandit\ncVaR: {:.2f} vs {:.2f}'.format(
            N,
            mapping_name[bandit],
            model.MAB[0].risk_measures['cvar'],
            model.MAB[1].risk_measures['cvar'],
        )
    )

    plt.tight_layout()
    plt.show()
